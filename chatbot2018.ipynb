# %%
pwd
# Out:
# 'D:\\python3'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#     Complete output from command python setup.py egg_info:
# ...
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\kusha\AppData\Local\Temp\pip-install-g3sqs858\ruamel.yaml\setup.py", line 858, in <module>
#         main()
#       File "C:\Users\kusha\AppData\Local\Temp\pip-install-g3sqs858\ruamel.yaml\setup.py", line 847, in main
#         setup(**kw)
#       File "D:\python3\lib\site-packages\setuptools\__init__.py", line 140, in setup
#         return distutils.core.setup(**attrs)
#       File "D:\python3\lib\distutils\core.py", line 108, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "D:\python3\lib\site-packages\setuptools\dist.py", line 370, in __init__
#         k: v for k, v in attrs.items()
#       File "D:\python3\lib\distutils\dist.py", line 267, in __init__
#         getattr(self.metadata, "set_" + key)(val)
#       File "D:\python3\lib\distutils\dist.py", line 1203, in set_keywords
# ...

# %%
pwd

# %%
# !pip install --user -r requirements.txt
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/9e/96/2013c227d1a98bb501f8fdca217e464f52896dd25fabdebfb30a25b41752/ChatterBot-0.7.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/28/96/a2413f8dd64feb6c8b9d7ef37c3c054fad4d0dfd6915577d939b67269210/chatterbot_corpus-1.0.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/f3/25/7b4f6d7536b98bc484b429568282496740bec1b2813cb718180585526d4a/jsondatabase-0.1.7-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/10/aa/f31c8a858e23fe5b14c59e6a03ae80b4cb76353c184df48a582a55eb2674/ruamel.yaml-0.15.0.tar.gz
#     Complete output from command python setup.py egg_info:
# ...
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\kusha\AppData\Local\Temp\pip-install-1yzty9f8\ruamel.yaml\setup.py", line 858, in <module>
#         main()
# ...

# %%
# !python -m app.py
# Out:
# ai.yml Training: [                    ] 1%
# ai.yml Training: [                    ] 2%
# ai.yml Training: [#                   ] 3%
# ai.yml Training: [#                   ] 4%
# ai.yml Training: [#                   ] 5%
# ai.yml Training: [#                   ] 6%
# ai.yml Training: [#                   ] 7%
# ai.yml Training: [##                  ] 8%
# ai.yml Training: [##                  ] 9%
# ai.yml Training: [##                  ] 10%
# ai.yml Training: [##                  ] 10%
# ai.yml Training: [##                  ] 11%
# ai.yml Training: [##                  ] 12%
# ai.yml Training: [###                 ] 13%
# ai.yml Training: [###                 ] 14%
# ai.yml Training: [###                 ] 15%
# ai.yml Training: [###                 ] 16%
# ai.yml Training: [###                 ] 17%
# ai.yml Training: [####                ] 18%
# ai.yml Training: [####                ] 19%
# ai.yml Training: [####                ] 20%
# ...
