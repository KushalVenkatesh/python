# %%
pwd
# Out:
# 'D:\\python3'

# %%
ls
# Out:
#  Volume in drive D is RECOVERY
#  Volume Serial Number is B8C5-8737
#
#  Directory of D:\python3
#
# 21-Dec-18  06:23 PM    <DIR>          .
# 21-Dec-18  06:23 PM    <DIR>          ..
# 21-Dec-18  04:04 PM    <DIR>          .ipynb_checkpoints
# 29-Nov-18  09:29 PM    <DIR>          __pycache__
# 21-Dec-18  03:55 PM            13,302 1T_14122018D224E36A0DCB49F98D7DD0672025E8D9.XLSX
# 20-Apr-18  06:58 PM            19,208 api-ms-win-core-console-l1-1-0.dll
# 20-Apr-18  06:58 PM            18,696 api-ms-win-core-datetime-l1-1-0.dll
# 20-Apr-18  06:58 PM            18,696 api-ms-win-core-debug-l1-1-0.dll
# 20-Apr-18  06:58 PM            18,696 api-ms-win-core-errorhandling-l1-1-0.dll
# 20-Apr-18  06:59 PM            22,280 api-ms-win-core-file-l1-1-0.dll
# 20-Apr-18  07:07 PM            18,696 api-ms-win-core-file-l1-2-0.dll
# 20-Apr-18  07:07 PM            18,696 api-ms-win-core-file-l2-1-0.dll
# 20-Apr-18  07:07 PM            18,696 api-ms-win-core-handle-l1-1-0.dll
# ...

# %%
import pandas as pd
import io
import requests
import urllib

# %%
df = pd.read_excel('6T_1412201814A120B6C7D6480C9043C96D01B16754.xlsx', skiprows=3)

# %%
df
# Out:
#     Unnamed: 0                                               Item  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                 M3
# 5          NaN                    1 Components (1.1.+1.2+1.3+1.4)
# 6          NaN                       1.1 Currency with the Public
# 7          NaN                     1.2 Demand Deposits with Banks
# 8          NaN                       1.3 Time Deposits with Banks
# 9          NaN             1.4 ‘Other’ Deposits with Reserve Bank
# 10         NaN                    2 Sources (2.1+2.2+2.3+2.4–2.5)
# 11         NaN                  2.1 Net Bank Credit to Government
# 12         NaN                                 2.1.1 Reserve Bank
# ...

# %%
df.drop(['Unnamed: 0'], axis=1)
# Out:
#                                                  Item Outstanding as on  \
# 0                                                 NaN              2018
# 1                                                 NaN               NaN
# 2                                                 NaN           Mar. 31
# 3                                                 NaN                 1
# 4                                                  M3            139626
# 5                     1 Components (1.1.+1.2+1.3+1.4)               NaN
# 6                        1.1 Currency with the Public           17597.1
# 7                      1.2 Demand Deposits with Banks           14837.1
# 8                        1.3 Time Deposits with Banks            106953
# 9              1.4 ‘Other’ Deposits with Reserve Bank             239.1
# 10                    2 Sources (2.1+2.2+2.3+2.4–2.5)               NaN
# 11                  2.1 Net Bank Credit to Government             40014
# ...
